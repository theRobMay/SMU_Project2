# %%
# Import dependencies
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 400)
# Import the Numpy dependency
from datetime import datetime as dt
import json

# %% [markdown]
# ### Extract the crowdfunding.xlsx Data

# %%
# Raj------added here....
# Read the data into a Pandas DataFrame
category_df2 = pd.read_csv('./Resources/category.csv')
category_df2.head()
# Out:
#   category_id      category
# 0        cat1          food
# 1        cat2         music
# 2        cat3    technology
# 3        cat4       theater
# 4        cat5  film & video

# %%
# Raj------added here....
# Read the data into a Pandas DataFrame
subcategory_df2 = pd.read_csv('./Resources/subcategory.csv')
subcategory_df2.head()
# Out:
#   subcategory_id  subcategory
# 0        subcat1  food trucks
# 1        subcat2         rock
# 2        subcat3          web
# 3        subcat4        plays
# 4        subcat5  documentary

# %%
# Raj------added here....
# Read the data into a Pandas DataFrame
contacts_df = pd.read_csv('./Resources/contacts.csv')
contacts_df.head()
# Out:
#    contact_id first_name last_name                         email
# 0        4661    Cecilia   Velasco  cecilia.velasco@rodrigues.fr
# 1        3765    Mariana     Ellis       mariana.ellis@rossi.org
# 2        4187      Sofie     Woods       sofie.woods@riviere.com
# 3        4941   Jeanette  Iannotti   jeanette.iannotti@yahoo.com
# 4        2199     Samuel   Sorgatz      samuel.sorgatz@gmail.com

# %%
# Raj------added here....
# Read the data into a Pandas DataFrame
campaign_df2 = pd.read_csv('./Resources/campaign.csv')
campaign_df2.head()
# Out:
#    cf_id  contact_id                company_name  \
# 0    147        4661  Baldwin, Riley and Jackson
# 1   1175        2288               Werner-Bryant
# 2    873        2067                 Stewart LLC
# 3   2568        5989              Castillo-Carey
# 4   1211        3307      Wright, Hartman and Yu
#
#                                             description      goal  pledged  \
# 0                  Pre-emptive tertiary standardization     100.0      0.0
# 1                                 Virtual uniform frame    1800.0   7991.0
# 2                    Cloned bi-directional architecture    1300.0  12047.0
# 3  Cross-platform solution-oriented process improvement  142400.0  21307.0
# 4                          User-friendly tertiary array    3300.0  12437.0
#
#       outcome  backers_count country currency launched_date    end_date  \
# 0      failed              0      CA      CAD    2020-02-13  2021-03-01
# ...

# %%
##***************************************================================

# %%
# Raj------added here....
category_df2.to_sql("category", con=engine, if_exists="append", method="multi", index=False)
# Out:
# 9

# %%
# Raj------added here....
subcategory_df2.to_sql("subcategory", con=engine, if_exists="append", method="multi", index=False)
# Out:
# 24

# %%
# Raj------added here....
contacts_df.to_sql("contacts", con=engine, if_exists="append", method="multi", index=False)
# Out:
# 1000

# %%
# Raj------added here....
campaign_df2.to_sql("campaign", con=engine, if_exists="append", method="multi", index=False)
# Out:
# 1000

# %%
#
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/etl_proj2')
query = 'SELECT * FROM category' 
df = pd.read_sql(query, engine)
df
#engine.dispose()
# Out:
#    category_id      category
# 0        cat01          food
# 1        cat02         music
# 2        cat03    technology
# 3        cat04       theater
# 4        cat05  film & video
# 5        cat06    publishing
# 6        cat07         games
# 7        cat08   photography
# 8        cat09    journalism
# 9         cat1          food
# 10        cat2         music
# 11        cat3    technology
# 12        cat4       theater
# 13        cat5  film & video
# 14        cat6    publishing
# 15        cat7         games
# 16        cat8   photography
# 17        cat9    journalism

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/etl_proj2')
query = 'SELECT * FROM subcategory' 
df = pd.read_sql(query, engine)
df
# Out:
#    subcategory_id        subcategory
# 0          scat01        food trucks
# 1          scat02               rock
# 2          scat03                web
# 3          scat04              plays
# 4          scat05        documentary
# 5          scat06     electric music
# 6          scat07              drama
# 7          scat08         indie rock
# 8          scat09          wearables
# 9         scat010         nonfiction
# 10        scat011          animation
# 11        scat012        video games
# 12        scat013             shorts
# 13        scat014            fiction
# 14        scat015  photography books
# 15        scat016   radio & podcasts
# 16        scat017              metal
# 17        scat018               jazz
# 18        scat019       translations
# 19        scat020         television
# 20        scat021       mobile games
# 21        scat022        world music
# 22        scat023    science fiction
# 23        scat024              audio
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/etl_proj2')
query = 'SELECT * FROM contacts' 
df = pd.read_sql(query, engine)
df
# Out:
#     contact_id    first_name   last_name  \
# 0         4661       Cecilia     Velasco
# 1         3765       Mariana       Ellis
# 2         4187         Sofie       Woods
# 3         4941      Jeanette    Iannotti
# 4         2199        Samuel     Sorgatz
# ..         ...           ...         ...
# 995       3684       Whitney       Noack
# 996       5784     Gelsomina  Migliaccio
# 997       1498   Evangelista     Pereira
# 998       6073        Gareth     Comolli
# 999       4939  Michelangelo        Hess
#
#                                          email
# 0                 cecilia.velasco@rodrigues.fr
# 1                      mariana.ellis@rossi.org
# 2                      sofie.woods@riviere.com
# 3                  jeanette.iannotti@yahoo.com
# 4                     samuel.sorgatz@gmail.com
# ..                                         ...
# 995             whitney.noack@laboratorios.org
# 996              gelsomina.migliaccio@junk.com
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/etl_proj2')
query = 'SELECT * FROM campaign' 
df = pd.read_sql(query, engine)
df
# Out:
# Empty DataFrame
# Columns: [cf_id, contact_id, company_name, description, goal, pledged, outcome, backers_count, country, currency, launched_at, deadline, category_id, subcategory_id]
# Index: []

# %%
#**********************************************************************--------
